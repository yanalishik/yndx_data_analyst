# %% [markdown]
# ### Описание проекта

# %% [markdown]
# ##### Аналитика средствами Python
# У нас есть файлы, в которых содержатся результаты SQL-запросов из предыдущих заданий.
#
# **_<span style="color:blue">query_1.csv</span>_** — результат первого запроса. В нём содержится информация о: model — модели самолета flights_amount — количество рейсов для каждой модели самолетов model в сентябре 2018 года
#
# **_<span style="color:blue">query_3.csv</span>_** — результат третьего запроса. В нём содержится информация о: city — городах average_flights — среднем количестве рейсов, прибывающих в город city за день в сентябре 2018 года

# %% [markdown]
# ##### Для этих двух наборов данных нужно:
# - импортировать файлы;
# - изучить данные в них;
# - проверить типы данных на корректность;
# - выбрать топ-10 городов по количеству рейсов
#
# ##### Построить графики и сделать выводы по каждому из графиков:
# - модели самолетов и количество рейсов,
# - город и количество рейсов,
# - топ-10 городов и количество рейсов.

# %% [markdown]
# Импортируем библиотеки:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
model_flights = pd.read_csv('/datasets/query_1.csv')
city_flights = pd.read_csv('/datasets/query_3.csv')

# %% [markdown]
# ###### Смотрим данные по количеству совершенных полетов по каждой модели самолета:

# %%
(model_flights
             .style.set_caption('Данные по количеству совершенных полетов по каждой модели самолета')
)
# Out:
# <style  type="text/css" >
# </style><table id="T_f608bf36_f4b6_11ea_9794_02420a391546" ><caption>Данные по количеству совершенных полетов по каждой модели самолета</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model</th>        <th class="col_heading level0 col1" >flights_amount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f608bf36_f4b6_11ea_9794_02420a391546level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f608bf36_f4b6_11ea_9794_02420a391546row0_col0" class="data row0 col0" >Airbus A319-100</td>
#                         <td id="T_f608bf36_f4b6_11ea_9794_02420a391546row0_col1" class="data row0 col1" >607</td>
#             </tr>
#             <tr>
#                         <th id="T_f608bf36_f4b6_11ea_9794_02420a391546level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f608bf36_f4b6_11ea_9794_02420a391546row1_col0" class="data row1 col0" >Airbus A321-200</td>
#                         <td id="T_f608bf36_f4b6_11ea_9794_02420a391546row1_col1" class="data row1 col1" >960</td>
#             </tr>
#             <tr>
#                         <th id="T_f608bf36_f4b6_11ea_9794_02420a391546level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f608bf36_f4b6_11ea_9794_02420a391546row2_col0" class="data row2 col0" >Boeing 737-300</td>
#                         <td id="T_f608bf36_f4b6_11ea_9794_02420a391546row2_col1" class="data row2 col1" >630</td>
#             </tr>
#             <tr>
#                         <th id="T_f608bf36_f4b6_11ea_9794_02420a391546level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f608bf36_f4b6_11ea_9794_02420a391546row3_col0" class="data row3 col0" >Boeing 767-300</td>
#                         <td id="T_f608bf36_f4b6_11ea_9794_02420a391546row3_col1" class="data row3 col1" >600</td>
#             </tr>
#             <tr>
#                         <th id="T_f608bf36_f4b6_11ea_9794_02420a391546level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f608bf36_f4b6_11ea_9794_02420a391546row4_col0" class="data row4 col0" >Boeing 777-300</td>
#                         <td id="T_f608bf36_f4b6_11ea_9794_02420a391546row4_col1" class="data row4 col1" >300</td>
#             </tr>
#             <tr>
#                         <th id="T_f608bf36_f4b6_11ea_9794_02420a391546level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f608bf36_f4b6_11ea_9794_02420a391546row5_col0" class="data row5 col0" >Bombardier CRJ-200</td>
#                         <td id="T_f608bf36_f4b6_11ea_9794_02420a391546row5_col1" class="data row5 col1" >4446</td>
#             </tr>
#             <tr>
#                         <th id="T_f608bf36_f4b6_11ea_9794_02420a391546level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f608bf36_f4b6_11ea_9794_02420a391546row6_col0" class="data row6 col0" >Cessna 208 Caravan</td>
#                         <td id="T_f608bf36_f4b6_11ea_9794_02420a391546row6_col1" class="data row6 col1" >4557</td>
#             </tr>
#             <tr>
#                         <th id="T_f608bf36_f4b6_11ea_9794_02420a391546level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f608bf36_f4b6_11ea_9794_02420a391546row7_col0" class="data row7 col0" >Sukhoi SuperJet-100</td>
#                         <td id="T_f608bf36_f4b6_11ea_9794_02420a391546row7_col1" class="data row7 col1" >4185</td>
#             </tr>
#     </tbody></table>

# %%
model_flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
# model             8 non-null object
# flights_amount    8 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 256.0+ bytes

# %% [markdown]
# Типы данных корректны. Пропуски отсутствуют.
# Данные имею подходящий формат.

# %% [markdown]
# ###### Строим график: модели самолётов и количество совершённых полётов.

# %%
(model_flights.sort_values(by='flights_amount', ascending=False).reset_index(drop=True).style
                                        .bar(subset=['flights_amount'], color='#497df5', vmin=0, width=100)
                                        .set_caption('Количество совершенных полетов по каждой модели самолета')
)
# Out:
# <style  type="text/css" >
#     #T_f60ebb3e_f4b6_11ea_9794_02420a391546row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#497df5 100.0%, transparent 100.0%);
#         }    #T_f60ebb3e_f4b6_11ea_9794_02420a391546row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#497df5 97.6%, transparent 97.6%);
#         }    #T_f60ebb3e_f4b6_11ea_9794_02420a391546row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#497df5 91.8%, transparent 91.8%);
#         }    #T_f60ebb3e_f4b6_11ea_9794_02420a391546row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#497df5 21.1%, transparent 21.1%);
#         }    #T_f60ebb3e_f4b6_11ea_9794_02420a391546row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#497df5 13.8%, transparent 13.8%);
#         }    #T_f60ebb3e_f4b6_11ea_9794_02420a391546row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#497df5 13.3%, transparent 13.3%);
#         }    #T_f60ebb3e_f4b6_11ea_9794_02420a391546row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#497df5 13.2%, transparent 13.2%);
#         }    #T_f60ebb3e_f4b6_11ea_9794_02420a391546row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#497df5 6.6%, transparent 6.6%);
#         }</style><table id="T_f60ebb3e_f4b6_11ea_9794_02420a391546" ><caption>Количество совершенных полетов по каждой модели самолета</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model</th>        <th class="col_heading level0 col1" >flights_amount</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f60ebb3e_f4b6_11ea_9794_02420a391546level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f60ebb3e_f4b6_11ea_9794_02420a391546row0_col0" class="data row0 col0" >Cessna 208 Caravan</td>
#                         <td id="T_f60ebb3e_f4b6_11ea_9794_02420a391546row0_col1" class="data row0 col1" >4557</td>
#             </tr>
#             <tr>
#                         <th id="T_f60ebb3e_f4b6_11ea_9794_02420a391546level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f60ebb3e_f4b6_11ea_9794_02420a391546row1_col0" class="data row1 col0" >Bombardier CRJ-200</td>
#                         <td id="T_f60ebb3e_f4b6_11ea_9794_02420a391546row1_col1" class="data row1 col1" >4446</td>
#             </tr>
#             <tr>
#                         <th id="T_f60ebb3e_f4b6_11ea_9794_02420a391546level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f60ebb3e_f4b6_11ea_9794_02420a391546row2_col0" class="data row2 col0" >Sukhoi SuperJet-100</td>
#                         <td id="T_f60ebb3e_f4b6_11ea_9794_02420a391546row2_col1" class="data row2 col1" >4185</td>
#             </tr>
#             <tr>
#                         <th id="T_f60ebb3e_f4b6_11ea_9794_02420a391546level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f60ebb3e_f4b6_11ea_9794_02420a391546row3_col0" class="data row3 col0" >Airbus A321-200</td>
#                         <td id="T_f60ebb3e_f4b6_11ea_9794_02420a391546row3_col1" class="data row3 col1" >960</td>
#             </tr>
#             <tr>
#                         <th id="T_f60ebb3e_f4b6_11ea_9794_02420a391546level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f60ebb3e_f4b6_11ea_9794_02420a391546row4_col0" class="data row4 col0" >Boeing 737-300</td>
#                         <td id="T_f60ebb3e_f4b6_11ea_9794_02420a391546row4_col1" class="data row4 col1" >630</td>
#             </tr>
#             <tr>
#                         <th id="T_f60ebb3e_f4b6_11ea_9794_02420a391546level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f60ebb3e_f4b6_11ea_9794_02420a391546row5_col0" class="data row5 col0" >Airbus A319-100</td>
#                         <td id="T_f60ebb3e_f4b6_11ea_9794_02420a391546row5_col1" class="data row5 col1" >607</td>
#             </tr>
#             <tr>
#                         <th id="T_f60ebb3e_f4b6_11ea_9794_02420a391546level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f60ebb3e_f4b6_11ea_9794_02420a391546row6_col0" class="data row6 col0" >Boeing 767-300</td>
#                         <td id="T_f60ebb3e_f4b6_11ea_9794_02420a391546row6_col1" class="data row6 col1" >600</td>
#             </tr>
#             <tr>
#                         <th id="T_f60ebb3e_f4b6_11ea_9794_02420a391546level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f60ebb3e_f4b6_11ea_9794_02420a391546row7_col0" class="data row7 col0" >Boeing 777-300</td>
#                         <td id="T_f60ebb3e_f4b6_11ea_9794_02420a391546row7_col1" class="data row7 col1" >300</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Смотрим данные по среднему количеству рейсов в день по городам:

# %%
city_flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 2 columns):
# city               101 non-null object
# average_flights    101 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# Типы данных корректны. Пропуски отсутствуют.
# Данные имею подходящий формат.

# %%
(city_flights
             .style.set_caption('Данные по среднему количеству рейсов в день по городам')
)
# Out:
# <style  type="text/css" >
# </style><table id="T_f612312e_f4b6_11ea_9794_02420a391546" ><caption>Данные по среднему количеству рейсов в день по городам</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >city</th>        <th class="col_heading level0 col1" >average_flights</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row0_col0" class="data row0 col0" >Абакан</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row0_col1" class="data row0 col1" >3.87097</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row1_col0" class="data row1 col0" >Анадырь</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row1_col1" class="data row1 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row2_col0" class="data row2 col0" >Анапа</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row2_col1" class="data row2 col1" >2.16129</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row3_col0" class="data row3 col0" >Архангельск</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row3_col1" class="data row3 col1" >5.35484</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row4_col0" class="data row4 col0" >Астрахань</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row4_col1" class="data row4 col1" >2.45161</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row5_col0" class="data row5 col0" >Барнаул</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row5_col1" class="data row5 col1" >2.6129</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row6_col0" class="data row6 col0" >Белгород</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row6_col1" class="data row6 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row7_col0" class="data row7 col0" >Белоярский</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row7_col1" class="data row7 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row8_col0" class="data row8 col0" >Благовещенск</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row8_col1" class="data row8 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row9_col0" class="data row9 col0" >Братск</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row9_col1" class="data row9 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row10_col0" class="data row10 col0" >Брянск</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row10_col1" class="data row10 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row11_col0" class="data row11 col0" >Бугульма</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row11_col1" class="data row11 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row12_col0" class="data row12 col0" >Владивосток</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row12_col1" class="data row12 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row13_col0" class="data row13 col0" >Владикавказ</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row13_col1" class="data row13 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row14_col0" class="data row14 col0" >Волгоград</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row14_col1" class="data row14 col1" >5.12903</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row15_col0" class="data row15 col0" >Воркута</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row15_col1" class="data row15 col1" >4.58065</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row16_col0" class="data row16 col0" >Воронеж</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row16_col1" class="data row16 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row17_col0" class="data row17 col0" >Геленджик</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row17_col1" class="data row17 col1" >2.59091</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row18_col0" class="data row18 col0" >Горно-Алтайск</td>
#                         <td id="T_f612312e_f4b6_11ea_9794_02420a391546row18_col1" class="data row18 col1" >1.3871</td>
#             </tr>
#             <tr>
#                         <th id="T_f612312e_f4b6_11ea_9794_02420a391546level0_row19" class="row_heading le

# %% [markdown]
# ###### Посмотрим на барплот по среднему количеству вылетов в каждом из городов. Здесть же выделим топ-10 (красным цветом):

# %%
city_flights = city_flights.sort_values(by='average_flights', ascending=False).reset_index(drop=True)
top10_subset = pd.IndexSlice[city_flights.iloc[:10,1].index, 'average_flights']
(city_flights.style.bar(subset=['average_flights'], color = '#f5f549')
                   .bar(subset=top10_subset, color='#ff5050', vmin=0)
                   .set_caption('Данные по среднему количеству рейсов в день по городам')
)
# Out:
# <style  type="text/css" >
#     #T_f627b684_f4b6_11ea_9794_02420a391546row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff5050 100.0%, transparent 100.0%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 23.4%, transparent 23.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff5050 24.0%, transparent 24.0%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 12.7%, transparent 12.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff5050 13.3%, transparent 13.3%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 8.2%, transparent 8.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff5050 8.9%, transparent 8.9%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 8.0%, transparent 8.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff5050 8.7%, transparent 8.7%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 7.1%, transparent 7.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff5050 7.9%, transparent 7.9%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 7.1%, transparent 7.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff5050 7.8%, transparent 7.8%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 7.0%, transparent 7.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff5050 7.7%, transparent 7.7%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 6.7%, transparent 6.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff5050 7.4%, transparent 7.4%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 6.7%, transparent 6.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff5050 7.4%, transparent 7.4%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 6.2%, transparent 6.2%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 6.0%, transparent 6.0%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 5.8%, transparent 5.8%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 5.7%, transparent 5.7%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 5.2%, transparent 5.2%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 4.6%, transparent 4.6%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 4.4%, transparent 4.4%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 4.3%, transparent 4.3%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 4.1%, transparent 4.1%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 4.1%, transparent 4.1%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row20_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 3.9%, transparent 3.9%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row21_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 3.9%, transparent 3.9%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row22_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 3.9%, transparent 3.9%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row23_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 3.9%, transparent 3.9%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row24_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 3.8%, transparent 3.8%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row25_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 3.8%, transparent 3.8%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row26_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 3.4%, transparent 3.4%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row27_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 3.2%, transparent 3.2%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row28_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 3.1%, transparent 3.1%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row29_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 3.1%, transparent 3.1%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row30_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 3.0%, transparent 3.0%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row31_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 2.8%, transparent 2.8%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row32_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f5f549 2.6%, transparent 2.6%);
#         }    #T_f627b684_f4b6_11ea_9794_02420a391546row33_col1 {
#             width:  10em;
#              height:

# %% [markdown]
# ### Итого имеем:
# ###### 1. С большим отрывом лидируют 3 модели воздушных судов: Цессна 208, Бомбардье 200 и Сухой 100. Неожиданностью явилось то, что на первом месте Цессна, ведь она используется на перелётах малой дальности.
#
# ###### 2. Ожидаемо, что на первом месте Москва  — это загруженный транспортный узел. Питер и Новосибирск занимают 2 и 3 места соответственно. Остальные города примерно на одном уровне..
